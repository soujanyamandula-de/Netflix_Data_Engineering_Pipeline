# %% [markdown]
# ## Silver Notebook Lookup Tables

# %% [markdown]
# ## Parameters

# %%
dbutils.widgets.text("sourcefolder","Netflix_directors")
dbutils.widgets.text("targetfolder","Netflix_directors")

# %% [markdown]
# ## Variables

# %%
var_src_folder=dbutils.widgets.get("sourcefolder")
var_tgt_folder=dbutils.widgets.get("targetfolder")

# %%
df = spark.read.format("csv")\
    .option("header", "true")\
    .option("inferSchema", "true")\
    .load(f"abfss://bronze@adlsaccglossdev.dfs.core.windows.net/{var_src_folder}")

# %%
df.write.format("delta")\
    .mode("overwrite")\
    .option("path",f"abfss://silver@adlsaccglossdev.dfs.core.windows.net/{var_tgt_folder}")\
    .save()
